# %%
import numpy as np
import sys
sys.path.insert(0, "/home/federico/Documents/GitHub")
from KID_pipeline import Target, functions as fc

# %matplotlib widget

# %%
t0530 = Target("20240207_133851", temperature=127, label="0530", ROACH='OLIMPO', build_dataset=True)
t1025 = Target("20240207_132922", temperature=127, label="1025", ROACH='OLIMPO', build_dataset=True)
t1520 = Target("20240207_135828", temperature=127, label="1520", ROACH='OLIMPO', build_dataset=True)
t2015 = Target("20240207_141006", temperature=127, label="2015", ROACH='OLIMPO', build_dataset=True)
t3005 = Target("20240207_143007", temperature=127, label="3005", ROACH='OLIMPO', build_dataset=True)

t2500 = Target("20240207_154610", temperature=127, label="2500", ROACH='OLIMPO', build_dataset=True)
t2505 = Target("20240207_141336", temperature=127, label="2505", ROACH='OLIMPO', build_dataset=True)
t2510 = Target("20240207_142618", temperature=127, label="2510", ROACH='OLIMPO', build_dataset=True)
t2515 = Target("20240207_153454", temperature=127, label="2515", ROACH='OLIMPO', build_dataset=True)
t2520 = Target("20240207_153738", temperature=127, label="2520", ROACH='OLIMPO', build_dataset=True)
t2525 = Target("20240207_154116", temperature=127, label="2525", ROACH='OLIMPO', build_dataset=True)
t2530 = Target("20240207_154351", temperature=127, label="2530", ROACH='OLIMPO', build_dataset=True)
#targets = [t2500, t2505, t2515, t2520, t2525, t2530]

t3000 = Target("20240207_155752", temperature=127, label="3000", ROACH='OLIMPO', build_dataset=True)
t3005 = Target("20240207_143007", temperature=127, label="3005", ROACH='OLIMPO', build_dataset=True)
t3010 = Target("20240207_160059", temperature=127, label="3010", ROACH='OLIMPO', build_dataset=True)
t3015 = Target("20240207_160436", temperature=127, label="3015", ROACH='OLIMPO', build_dataset=True)
t3020 = Target("20240207_160653", temperature=127, label="3020", ROACH='OLIMPO', build_dataset=True)
t3025 = Target("20240207_160909", temperature=127, label="3025", ROACH='OLIMPO', build_dataset=True)
t3030 = Target("20240207_161131", temperature=127, label="3030", ROACH='OLIMPO', build_dataset=True)
#targets = [t3000, t3005, t3015, t3020, t3025, t3030]

# con 20dB di attenuatore hardware in piu
t3000_20 = Target("20240207_163324", temperature=127, label="3000", ROACH='OLIMPO', build_dataset=True)
t2500_20 = Target("20240207_163839", temperature=127, label="2500", ROACH='OLIMPO', build_dataset=True)
t2000_20 = Target("20240207_164125", temperature=127, label="2000", ROACH='OLIMPO', build_dataset=True)
t0510_20 = Target("20240207_165630", temperature=127, label="0510", ROACH='OLIMPO', build_dataset=True)
targets = [t3000_20, t2500_20, t2000_20, t0510_20, t2510]
# Out:
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
# Reading target sweep 20240207_133851...
# 124 entries found.
#
# Building S21 dataset from raw data sweep...
# 	OLIMPO ROACH selected (freqs = LO/2 + bb)
# ...
# 	Computing frequencies... : 100%|███████████| 124/124 [00:00<00:00, 1054.57it/s]
# Looking for out of resonance tones...
# 	average depth: 25.901761dB
# 	std depth: 8.741403dB
# 	discarding tones with depth less than 8.418956dB
# 	Found 7 out of resonance tones:
# 		Channel 14 - 228.747000 MHz
# 		Channel 31 - 254.242500 MHz
# 		Channel 53 - 291.462000 MHz
# 		Channel 74 - 337.615000 MHz
# 		Channel 121 - 189.970000 MHz
# 		Channel 122 - 299.972500 MHz
# 		Channel 123 - 406.972500 MHz
#
# Complex fit parameters not available for 124/117 resonances.
#
# Searching for multiple peaks...
# 	Found  2  peaks in channel  3
# 	Found  2  peaks in channel  26
# 	Found  2  peaks in channel  34
# 	Found  2  peaks in channel  68
# 	Found  2  peaks in channel  83
# ...

# %%
fc.overplotTargetSweeps(targets, add_out_of_res_plot=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fc.overplotTargetCircles(targets=[t0530, t1025], only_idxs=[31], )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
t0530.get_Qraw(31)
# Out:
# array([-4.51954790e-07, -4.54167606e-07, -4.56815700e-07, -4.58566152e-07,
#        -4.61088140e-07, -4.63298048e-07, -4.66017633e-07, -4.69755751e-07,
#        -4.73756049e-07, -4.79253379e-07, -4.87830341e-07, -4.96514156e-07,
#        -4.90229965e-07, -4.83711065e-07, -4.78159194e-07, -4.72429195e-07,
#        -4.66803083e-07, -4.60767474e-07, -4.54701703e-07, -4.48518427e-07,
#        -4.42944081e-07, -4.36778135e-07, -4.31143655e-07, -4.24969888e-07,
#        -4.19519167e-07, -4.14517417e-07, -4.08466716e-07, -4.02866342e-07,
#        -3.96962538e-07, -3.91189310e-07, -3.85423370e-07, -3.79863360e-07,
#        -3.74195033e-07, -3.69057052e-07, -3.63015732e-07, -3.57762611e-07,
#        -3.52510496e-07, -3.46109646e-07, -3.41300338e-07, -3.34957466e-07,
#        -3.30822590e-07, -3.25906173e-07, -3.21147233e-07, -3.15700660e-07,
#        -3.10347489e-07, -3.04924701e-07, -2.99426485e-07, -3.05966354e-07,
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(t0530.get_freqs(31), t0530.get_magdB(31))

plt.plot(t3005.get_freqs(31), t3005.get_magdB(31))

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
t0530.entry[31]
# Out:
# {'target_freq': 254.2425,
#  'channel': 31,
#  'depth': 1.9150599277786426,
#  'is_out_of_res': True,
#  'number_of_peaks': None,
#  'peaks': None,
#  'Re[a]': None,
#  'Im[a]': None,
#  'Q_tot': None,
#  'Q_i': None,
#  'Q_c': None,
#  'nu_r': None,
#  'phi_0': None,
#  'reduced_chi2': None}
